# %%
print("welcome to  the shopping complexx")
print("please enter where you want to go in ADMIN(1)  USER (2),BROWSE(3)")
user=input()
if(user=="ADMIN"):
	print("welcome to the admin section")
	print("please enter the credentials \n login id: \n password")
	loginid=input('ENTER YOUR EMAIL')
	password=input('ENTER YOUR EMAIL PASSWORD')
	print("welcome admin sir")
	print("what you want to do STOCK CHECK(1)  RATE PRICE(2)  ")
	user=int(input("1. STOCK CHECK  \n  2. RATE PRICE \n"))
	if(user==1):
		print("welcome to the stock section")
		print("here is the list of stock available in the store")
		S={"Grocery":56,"Stationary":85,"Elctronics devices":52,"Mens wear":98,"footwear":100}
		print(S)
	elif(user==2):
		print("here is the rate list of the the stocks availale in the complexx") 
		print("1.Pulses:-80/- \n  2.Sugar:-40/- \n 3.Rice:-150/kg \n 4.soaps:-35/peice \n  5.Register:-60/- \n 6.Pens:-10/- \n 7.Marker sets:-50/- \n")
		print("thanx for visiting the admin section ")
elif(user=="USER"):
	print("welcome to the user section")
	print("please enter your credentials")
	Loginid=input('ENTER YOUR MAIL')
	Password=input('PLS ENTER PASSWORD')
	print('''Which branch would you want to go
	(1)Grocery  Stationary
	(2)  Electronic devices
	(3)  Mens wear
	(4) Footwear
	(5) stationary''')
	user=int(input("1.Grocery \n 2.Stationary \n 3.Electronic devices \n 4.Mens wear \n 5.Footwear \n"))
	if(user==1):
		print("Welcome to the grocery")
		print("1.Pulses:-80/kg \n 2.Sugar:-42/kg \n 3.Rice:-120/kg \n 4.Soaps:-35/peice")
	elif(user==2):
		print("Welcome to stationary section")
		print("1.Register:-60/- \n 2.Pens:-10/- 3.Marker set:-60/- 4.Paper board:-60/-")
		print("Please make the order and select the items")
	elif(user==3):
		print("Welcome to the electronics section")
		print("1.Mobile Phones:-75000/- \n 2.LEDs:-58000/- \n 3.Laptops:-85000/- \n 4.Headphones:-2400/-")
		print("Please select the items and make the order")
	elif(user==4):
		print("Welcome to the Mens wear section")
		print("1.Trousers:-2000/- \n  2.Shirts:-1500/- \n  3.Leather Jackets:-2800/- \n  4.T-Shirts:-1500/-")
		print("Please select the items and make the order")
	elif(user==5):
		print("Welcome to the Footwear section")
		print("1.Loafers:-1500/- \n 2.Formal Shoes:-1500/- \n 3.Sleepers:-1000/- \n 4.Sports shoes:-2500/-")
	productname=input('pls enter product name how to choose')
	quantity=int(input('pls enter product quantity'))
	price=int(input('pls enter product price'))
	print("YOUR BILL IS RS",quantity*price)
if(user=="BROWSE"):
	print("Please select the items and make the order")
	print('''Which branch would you want to go
	1.Grocery  
	2.Stationary
	3.Electronic devices 
	4.Mens wear 
	5.Footwear''')
	user=input()
	if(user=='GROCERY'):
		print("Welcome to the grocery")
		print('''1.Pulses:-80/kg
		2.Sugar:-42/kg 
		3.Rice:-120/kg
		4.Soaps:-35/peice''')
		print("Please make the order and select the items ")
	elif(user=='STATIONARY'):
		print("Welcome to stationary section")
		print("1.Register:-60/- \n 2.Pens:-10/- 3.Marker set:-60/- 4.Paper board:-60/-")
		print("Please make the order and select the items")
	elif(user=='ELECTRONIC'):
		print("Welcome to the electronics section")
		print("1.Mobile Phones:-75000/- \n 2.LEDs:-58000/- \n 3.Laptops:-85000/- \n 4.Headphones:-2400/-")
		print("Please select the items and make the order")
	elif(user=='WEAR'):
		print("Welcome to the Mens wear section")
		print("1.Trousers:-2000/- \n  2.Shirts:-1500/- \n  3.Leather Jackets:-2800/- \n  4.T-Shirts:-1500/-")
		print("Please select the items and make the order")
	elif(user=='FOOTWEAR'):
		print("Welcome to the Footwear section")
		print("1.Loafers:-1500/- \n 2.Formal Shoes:-1500/- \n 3.Sleepers:-1000/- \n 4.Sports shoes:-2500/-")
		print("Please select the items and make the orde")
	select=input('pls enter how to select')
	print('you are not signup ot signin pls after that pls sign in ')
	print("login ID: \n Password: \n")
	LoginID=input()
	Password=input()
	productname=input('pls enter product name how to choose')
	productquantity=input('pls enter product quantity')
	productprice=input('pls enter product price')
	print('your bill is this amount',productquantity*productprice)
